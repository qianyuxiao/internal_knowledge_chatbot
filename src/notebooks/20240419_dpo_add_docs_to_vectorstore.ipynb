# %%
# !gsutil cp gs://ecg_dpo_2/me_parameters/ecg_dpo_2_me.json ../vector_store_me_parameters/
# Out:
# Copying gs://ecg_dpo_2/me_parameters/ecg_dpo_2_me.json...
# / [1 files][  390.0 B/  390.0 B]
# Operation completed over 1 objects/390.0 B.

# %%
import sys

# Add the directory to sys.path
sys.path.append('/home/qianyucazelles/internal_knowledge_chatbot/src')
from utils.doc_to_vertex_search import *
from utils.general_utils import *

from langchain.document_loaders import PyPDFLoader
from langchain_community.document_loaders import UnstructuredPDFLoader
import os

# %%
import nltk
def nb_tokens(text):
    return len(nltk.word_tokenize(text))

# %%
def load_pdf_to_langchain_doc(
    pdf_path,
    unstructure_loader: bool=True):
    
    if unstructure_loader:
        print("Using unstrucure loader")
        loader = UnstructuredPDFLoader(f'{pdf_path}')
    else:
        loader = PyPDFLoader(f'{pdf_path}')
    doc = loader.load()
    
    return doc

# %%
def pdf_to_vector_search(
    pdf_path,
    me,
    unstructure_loader: bool=False,
    split_to_article: bool=False
):
    print_with_time(f"Process file:{pdf_path} ")
    
    #load pages
    pages = load_pdf_to_langchain_doc(pdf_path,unstructure_loader)
    
    print_with_line(f"len of pages:{len(pages)}")
    
    #split to article
    if split_to_article:
        articles = split_pages_into_artiles(pages)
        doc_splits = doc_to_chunk(articles)
    else:
        doc_splits = doc_to_chunk(pages)
        

    print_with_line(f"n splits:{len(doc_splits)}")
    
    #add to vector store
    doc_ids = add_splits_to_vector_store(doc_splits,me)
    
    
    #log process
    if len(doc_ids)>0:
        
        print_with_line(f"Added to vector store with {len(doc_ids)} ids.")
        
        with open("../add_docs_to_vectorstore_logs/processed_pdfs.txt", "a") as f:
            f.write(f"'{pdf_path}',\n")
        with open("../add_docs_to_vectorstore_logs/processed_pdfs_doc_ids.txt", "a") as f:
            f.write(f"'{pdf_path}': {doc_ids},\n")
        
    else:
        
        print_with_star("No doc ids returned")
        
        with open(f"../add_docs_to_vectorstore_logs/unprocessed_pdfs.txt", "a") as f:
            f.write(f"'{pdf_path}'," + "\n")
            
    return doc_ids

# %%
def process_folder(me,CHATBOT_ID, folder_path, pdf_doc_ids, other_files):
    try:
        processed_pdfs = read_txt_to_list("../add_docs_to_vectorstore_logs/processed_pdfs.txt") 
    except:
        processed_pdfs = []    
    for item in os.listdir(folder_path):
        
        item_path = os.path.join(folder_path, item)
        print_with_time(f"Scanning {item_path}")
        
        if os.path.isdir(item_path):
            
            print_with_time(f"{item_path} is folder, now go to new level")
            process_folder(me,CHATBOT_ID,item_path,pdf_doc_ids, other_files)
            
        elif item.lower().endswith('.pdf'):
            if item not in processed_pdfs:
                
                print_with_time(f"{item_path} is pdf, now process to vector store")
                try:
                    
                    doc_ids = pdf_to_vector_search(item_path,me)
                    
                except Exception as e:
                    with open(f"../add_docs_to_vectorstore_logs/unprocessed_pdfs.txt", "a") as f:
                        f.write(f"'{item_path}'," + "\n")
                    print_with_star(f"An error occurred while processing {item_path}: {e}")
                    doc_ids=[]
                pdf_doc_ids[item_path]=doc_ids
            
        else:
            other_files.append(item_path)

# %%
def main(me,
         CHATBOT_ID: str,
         root_folder: str
         ):
    
    pdf_data = {}
    other_files = []
    
    process_folder(me,CHATBOT_ID,root_folder, pdf_data, other_files)
    
    # Writing PDF data to JSON file
    pdf_output_file = f"../add_docs_to_vectorstore_logs/{CHATBOT_ID}_pdf_doc_ids.json"
    with open(pdf_output_file, "w") as json_file:
        json.dump(pdf_data, json_file, indent=4)
    print(f"PDF data has been written to {pdf_output_file}")
    
    # Writing other files list to JSON file
    other_output_file = f"../add_docs_to_vectorstore_logs/{CHATBOT_ID}_non_pdf_files.json"
    with open(other_output_file, "w") as json_file:
        json.dump(other_files, json_file, indent=4)
    print(f"Non-PDF files list has been written to {other_output_file}")

# %%
root_folder = f"../documents/ecg_dpo/"

# %%
if __name__ == "__main__":
    CHATBOT_ID = "ecg_dpo"
    # root_folder = f"../documents/{CHATBOT_ID}/"
    # get embeddings
    embeddings = get_embeddings()

    #get parameters
    parameters = get_me_parameters(f'../vector_store_me_parameters/{CHATBOT_ID}_me.json')

    #get vector store
    me = get_vector_store(parameters, embeddings)
    
    main(me,CHATBOT_ID,root_folder)
# Out:
# Model_name will become a required arg for VertexAIEmbeddings starting from Feb-01-2024. Currently the default is set to textembedding-gecko@001
# [2024-04-19 17:01:18] Scanning ../documents/ecg_dpo/Code civil
# [2024-04-19 17:01:18] ../documents/ecg_dpo/Code civil is folder, now go to new level
# [2024-04-19 17:01:18] Scanning ../documents/ecg_dpo/Code civil/LEGITEXT000006070721.pdf
# [2024-04-19 17:01:18] ../documents/ecg_dpo/Code civil/LEGITEXT000006070721.pdf is pdf, now process to vector store
# [2024-04-19 17:01:18] Process file:../documents/ecg_dpo/Code civil/LEGITEXT000006070721.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:01:21] len of pages:679
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:01:21] n splits:679
# Waiting
# .....................................................................................................................................successfully added to vector store with 679 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:03:37] Added to vector store with 679 ids.
# [2024-04-19 17:03:37] Scanning ../documents/ecg_dpo/Code de la consommation
# [2024-04-19 17:03:37] ../documents/ecg_dpo/Code de la consommation is folder, now go to new level
# [2024-04-19 17:03:37] Scanning ../documents/ecg_dpo/Code de la consommation/LEGITEXT000006069565.pdf
# [2024-04-19 17:03:37] ../documents/ecg_dpo/Code de la consommation/LEGITEXT000006069565.pdf is pdf, now process to vector store
# [2024-04-19 17:03:37] Process file:../documents/ecg_dpo/Code de la consommation/LEGITEXT000006069565.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:03:41] len of pages:649
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:03:41] n splits:649
# Waiting
# ................................................................................................................................successfully added to vector store with 649 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:05:46] Added to vector store with 649 ids.
# [2024-04-19 17:05:46] Scanning ../documents/ecg_dpo/Code du travail
# [2024-04-19 17:05:46] ../documents/ecg_dpo/Code du travail is folder, now go to new level
# [2024-04-19 17:05:46] Scanning ../documents/ecg_dpo/Code du travail/LEGITEXT000006072050.pdf
# [2024-04-19 17:05:46] ../documents/ecg_dpo/Code du travail/LEGITEXT000006072050.pdf is pdf, now process to vector store
# [2024-04-19 17:05:46] Process file:../documents/ecg_dpo/Code du travail/LEGITEXT000006072050.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:06:05] len of pages:3381
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:06:05] n splits:3381
# Waiting
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................successfully added to vector store with 3381 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:16:39] Added to vector store with 3381 ids.
# [2024-04-19 17:16:39] Scanning ../documents/ecg_dpo/Code du tourisme
# [2024-04-19 17:16:39] ../documents/ecg_dpo/Code du tourisme is folder, now go to new level
# [2024-04-19 17:16:39] Scanning ../documents/ecg_dpo/Code du tourisme/LEGITEXT000006074073.pdf
# [2024-04-19 17:16:39] ../documents/ecg_dpo/Code du tourisme/LEGITEXT000006074073.pdf is pdf, now process to vector store
# [2024-04-19 17:16:39] Process file:../documents/ecg_dpo/Code du tourisme/LEGITEXT000006074073.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:16:40] len of pages:205
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:16:40] n splits:205
# Waiting
# ........................................successfully added to vector store with 205 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:19] Added to vector store with 205 ids.
# [2024-04-19 17:17:19] Scanning ../documents/ecg_dpo/CNIL
# [2024-04-19 17:17:19] ../documents/ecg_dpo/CNIL is folder, now go to new level
# [2024-04-19 17:17:19] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE II - Principes _ CNIL.pdf
# [2024-04-19 17:17:19] ../documents/ecg_dpo/CNIL/CHAPITRE II - Principes _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:19] Process file:../documents/ecg_dpo/CNIL/CHAPITRE II - Principes _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:20] len of pages:7
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:20] n splits:7
# Waiting
# .successfully added to vector store with 7 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:21] Added to vector store with 7 ids.
# [2024-04-19 17:17:21] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE I - Dispositions générales.pdf
# [2024-04-19 17:17:21] ../documents/ecg_dpo/CNIL/CHAPITRE I - Dispositions générales.pdf is pdf, now process to vector store
# [2024-04-19 17:17:21] Process file:../documents/ecg_dpo/CNIL/CHAPITRE I - Dispositions générales.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:22] len of pages:6
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:22] n splits:6
# Waiting
# .successfully added to vector store with 6 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:24] Added to vector store with 6 ids.
# [2024-04-19 17:17:24] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE XI - Dispositions finales _ CNIL.pdf
# [2024-04-19 17:17:24] ../documents/ecg_dpo/CNIL/CHAPITRE XI - Dispositions finales _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:24] Process file:../documents/ecg_dpo/CNIL/CHAPITRE XI - Dispositions finales _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:24] len of pages:3
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:24] n splits:3
# Waiting
# successfully added to vector store with 3 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:24] Added to vector store with 3 ids.
# [2024-04-19 17:17:24] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE V - Transferts de données à caractère personnel vers des pays tiers ou à des organisations internationales _ CNIL.pdf
# [2024-04-19 17:17:24] ../documents/ecg_dpo/CNIL/CHAPITRE V - Transferts de données à caractère personnel vers des pays tiers ou à des organisations internationales _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:24] Process file:../documents/ecg_dpo/CNIL/CHAPITRE V - Transferts de données à caractère personnel vers des pays tiers ou à des organisations internationales _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:25] len of pages:9
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:25] n splits:9
# Waiting
# .successfully added to vector store with 9 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:27] Added to vector store with 9 ids.
# [2024-04-19 17:17:27] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE VII - Coopération et cohérence _ CNIL.pdf
# [2024-04-19 17:17:27] ../documents/ecg_dpo/CNIL/CHAPITRE VII - Coopération et cohérence _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:27] Process file:../documents/ecg_dpo/CNIL/CHAPITRE VII - Coopération et cohérence _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:28] len of pages:15
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:28] n splits:15
# Waiting
# ..successfully added to vector store with 15 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:31] Added to vector store with 15 ids.
# [2024-04-19 17:17:31] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE VI - Autorités de contrôle indépendantes _ CNIL.pdf
# [2024-04-19 17:17:31] ../documents/ecg_dpo/CNIL/CHAPITRE VI - Autorités de contrôle indépendantes _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:31] Process file:../documents/ecg_dpo/CNIL/CHAPITRE VI - Autorités de contrôle indépendantes _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:32] len of pages:11
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:32] n splits:11
# Waiting
# ..successfully added to vector store with 11 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:34] Added to vector store with 11 ids.
# [2024-04-19 17:17:34] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE III - Droits de la personne concernée _ CNIL.pdf
# [2024-04-19 17:17:34] ../documents/ecg_dpo/CNIL/CHAPITRE III - Droits de la personne concernée _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:34] Process file:../documents/ecg_dpo/CNIL/CHAPITRE III - Droits de la personne concernée _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:35] len of pages:14
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:35] n splits:14
# Waiting
# ..successfully added to vector store with 14 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:38] Added to vector store with 14 ids.
# [2024-04-19 17:17:38] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE VIII - Voies de recours, responsabilité et sanctions _ CNIL.pdf
# [2024-04-19 17:17:38] ../documents/ecg_dpo/CNIL/CHAPITRE VIII - Voies de recours, responsabilité et sanctions _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:38] Process file:../documents/ecg_dpo/CNIL/CHAPITRE VIII - Voies de recours, responsabilité et sanctions _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:38] len of pages:7
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:38] n splits:7
# Waiting
# .successfully added to vector store with 7 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:40] Added to vector store with 7 ids.
# [2024-04-19 17:17:40] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE IX - Dispositions relatives à des situations particulières de traitement _ CNIL.pdf
# [2024-04-19 17:17:40] ../documents/ecg_dpo/CNIL/CHAPITRE IX - Dispositions relatives à des situations particulières de traitement _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:40] Process file:../documents/ecg_dpo/CNIL/CHAPITRE IX - Dispositions relatives à des situations particulières de traitement _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:40] len of pages:4
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:40] n splits:4
# Waiting
# successfully added to vector store with 4 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:41] Added to vector store with 4 ids.
# [2024-04-19 17:17:41] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE X - Actes délégués et actes d'exécution _ CNIL.pdf
# [2024-04-19 17:17:41] ../documents/ecg_dpo/CNIL/CHAPITRE X - Actes délégués et actes d'exécution _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:41] Process file:../documents/ecg_dpo/CNIL/CHAPITRE X - Actes délégués et actes d'exécution _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:41] len of pages:2
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:41] n splits:2
# Waiting
# successfully added to vector store with 2 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:42] Added to vector store with 2 ids.
# [2024-04-19 17:17:42] Scanning ../documents/ecg_dpo/CNIL/CHAPITRE IV - Responsable du traitement et sous-traitant _ CNIL.pdf
# [2024-04-19 17:17:42] ../documents/ecg_dpo/CNIL/CHAPITRE IV - Responsable du traitement et sous-traitant _ CNIL.pdf is pdf, now process to vector store
# [2024-04-19 17:17:42] Process file:../documents/ecg_dpo/CNIL/CHAPITRE IV - Responsable du traitement et sous-traitant _ CNIL.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:43] len of pages:23
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:43] n splits:23
# Waiting
# ....successfully added to vector store with 23 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:17:48] Added to vector store with 23 ids.
# [2024-04-19 17:17:48] Scanning ../documents/ecg_dpo/Code de commerce
# [2024-04-19 17:17:48] ../documents/ecg_dpo/Code de commerce is folder, now go to new level
# [2024-04-19 17:17:48] Scanning ../documents/ecg_dpo/Code de commerce/LEGITEXT000005634379.pdf
# [2024-04-19 17:17:48] ../documents/ecg_dpo/Code de commerce/LEGITEXT000005634379.pdf is pdf, now process to vector store
# [2024-04-19 17:17:48] Process file:../documents/ecg_dpo/Code de commerce/LEGITEXT000005634379.pdf
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:18:16] len of pages:3500
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:18:16] n splits:3500
# Waiting
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................successfully added to vector store with 3500 new doc ids
# ----------------------------------------------------------------------------------------------------
# [2024-04-19 17:29:14] Added to vector store with 3500 ids.
# PDF data has been written to ../add_docs_to_vectorstore_logs/ecg_dpo_2_pdf_doc_ids.json
# Non-PDF files list has been written to ../add_docs_to_vectorstore_logs/ecg_dpo_2_non_pdf_files.json
